# %%
import socket

# %%
html = """
<!Doctype html>
<html>
<body>
<h1 style='color:red'>Welcome to My Personal Web Server</h1>
<h2>I am Controller</h2>
<h3>Welcome to Web Page Powered By Python</h3>
</body>
</html>
"""


resp = f"""HTTP/1.1 200 OK
Content-Length: {len(html)}
Content-Type: text/html
Connection: Closed

{html}"""

# %%
import socket
server = socket.socket()
server.bind(('192.168.1.114',12345))
server.listen(100)
while True : 
    client,address = server.accept()
    print('Got a connection from ',address)
    print("Client Request ")
    request = client.recv(1024).decode()
    print(request)
    client.send(resp.encode())
    client.close()
server.close()
# Out:
# Got a connection from  ('192.168.1.122', 50016)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9
#
#
# Got a connection from  ('192.168.1.122', 50017)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9
#
#
# Got a connection from  ('192.168.1.118', 50883)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.118', 50884)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.123', 1905)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate
# Accept-Language: en-GB,en-US;q=0.9,en;q=0.8
#
#
# Got a connection from  ('192.168.1.123', 1906)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-GB,en-US;q=0.9,en;q=0.8
#
#
# Got a connection from  ('192.168.1.113', 50141)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9
#
#
# Got a connection from  ('192.168.1.113', 50142)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9
#
#
# Got a connection from  ('192.168.1.118', 50885)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.118', 50886)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.118', 50887)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.118', 50888)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.118', 50889)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.118', 50890)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.124', 59777)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9,hi;q=0.8
#
#
# Got a connection from  ('192.168.1.121', 65229)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9
#
#
# Got a connection from  ('192.168.1.121', 65230)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9
#
#
# Got a connection from  ('192.168.1.118', 50891)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.118', 50892)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
# Got a connection from  ('192.168.1.118', 50893)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.118', 50894)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7
#
#
# Got a connection from  ('192.168.1.124', 59776)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9,hi;q=0.8
#
#
# Got a connection from  ('192.168.1.106', 61233)
# Client Request
# GET / HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9
#
#
# Got a connection from  ('192.168.1.106', 61232)
# Client Request
# GET /favicon.ico HTTP/1.1
# Host: 192.168.1.114:12345
# Connection: keep-alive
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36
# Accept: image/webp,image/apng,image/*,*/*;q=0.8
# Referer: http://192.168.1.114:12345/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9
