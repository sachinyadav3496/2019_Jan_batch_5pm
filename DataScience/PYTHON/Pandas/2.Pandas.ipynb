# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
#Series 
s1 = pd.Series(data=np.random.randn(10),index=pd.date_range('20190101',periods=10),name='Growth')
s1
# Out:
# 2019-01-01   -0.189831
# 2019-01-02    0.360840
# 2019-01-03   -0.638129
# 2019-01-04    0.822342
# 2019-01-05    1.312669
# 2019-01-06    0.781300
# 2019-01-07   -1.396412
# 2019-01-08    1.356087
# 2019-01-09   -0.014878
# 2019-01-10    0.721986
# Freq: D, Name: Growth, dtype: float64

# %%
s1.to_csv('one.csv')

# %%
s1.to_csv('two.csv',index=False)

# %%
s = pd.read_csv('two.csv')

# %%
s
# Out:
#    -0.18983139644737582
# 0              0.360840
# 1             -0.638129
# 2              0.822342
# 3              1.312669
# 4              0.781300
# 5             -1.396412
# 6              1.356087
# 7             -0.014878
# 8              0.721986

# %%
data = np.random.random(80).reshape(20,4)*25

# %%
data
# Out:
# array([[13.37300461, 10.98002394, 24.60655233,  4.25994413],
#        [ 2.5257611 , 17.40172527, 16.98427719, 20.99480105],
#        [18.32827627, 23.16600732,  1.19748443, 15.91327612],
#        [ 6.99405006, 17.71156083, 19.1508304 ,  4.69546785],
#        [ 8.82011843,  0.67344946,  8.53373114, 11.26350803],
#        [ 3.00242408, 17.80634404, 20.33884823, 12.29260446],
#        [ 8.87431187,  6.76404479,  2.38892957,  6.5920397 ],
#        [12.93119194, 18.31356174, 22.25550028, 18.15423356],
#        [14.8938781 ,  9.52194687,  1.8052703 ,  4.20125834],
#        [ 2.96937633,  5.08924545, 18.01707315, 20.46443444],
#        [19.15855595, 13.10734126, 23.15369953,  5.784614  ],
#        [ 3.45985003, 24.79481805,  0.59116385, 10.02823812],
#        [ 5.40405743,  7.94272947, 18.22700038, 11.70558703],
#        [20.21173462, 21.92328828,  9.89658747,  4.55181035],
#        [12.1954115 , 11.50307074, 19.8279752 ,  1.15748662],
# ...

# %%
plt.plot(data)
plt.show()

# %%
sns.distplot(data,color=['r','b','g','b'])
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5557e030ca2b> in <module>
# ----> 1 sns.distplot(data,color=['r','b','g','b'])
#       2 plt.show()
#
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# ...

# %%
plt.hist(data,bins=10)
plt.show()

# %%
data
# Out:
# array([[13.37300461, 10.98002394, 24.60655233,  4.25994413],
#        [ 2.5257611 , 17.40172527, 16.98427719, 20.99480105],
#        [18.32827627, 23.16600732,  1.19748443, 15.91327612],
#        [ 6.99405006, 17.71156083, 19.1508304 ,  4.69546785],
#        [ 8.82011843,  0.67344946,  8.53373114, 11.26350803],
#        [ 3.00242408, 17.80634404, 20.33884823, 12.29260446],
#        [ 8.87431187,  6.76404479,  2.38892957,  6.5920397 ],
#        [12.93119194, 18.31356174, 22.25550028, 18.15423356],
#        [14.8938781 ,  9.52194687,  1.8052703 ,  4.20125834],
#        [ 2.96937633,  5.08924545, 18.01707315, 20.46443444],
#        [19.15855595, 13.10734126, 23.15369953,  5.784614  ],
#        [ 3.45985003, 24.79481805,  0.59116385, 10.02823812],
#        [ 5.40405743,  7.94272947, 18.22700038, 11.70558703],
#        [20.21173462, 21.92328828,  9.89658747,  4.55181035],
#        [12.1954115 , 11.50307074, 19.8279752 ,  1.15748662],
# ...

# %%
index = pd.date_range('20190101',periods=20)

# %%
df = pd.DataFrame(data=data,index=index,columns=['A','B','C','D'])

# %%
df
# Out:
#                     A          B          C          D
# 2019-01-01  13.373005  10.980024  24.606552   4.259944
# 2019-01-02   2.525761  17.401725  16.984277  20.994801
# 2019-01-03  18.328276  23.166007   1.197484  15.913276
# 2019-01-04   6.994050  17.711561  19.150830   4.695468
# 2019-01-05   8.820118   0.673449   8.533731  11.263508
# 2019-01-06   3.002424  17.806344  20.338848  12.292604
# 2019-01-07   8.874312   6.764045   2.388930   6.592040
# 2019-01-08  12.931192  18.313562  22.255500  18.154234
# 2019-01-09  14.893878   9.521947   1.805270   4.201258
# 2019-01-10   2.969376   5.089245  18.017073  20.464434
# 2019-01-11  19.158556  13.107341  23.153700   5.784614
# 2019-01-12   3.459850  24.794818   0.591164  10.028238
# 2019-01-13   5.404057   7.942729  18.227000  11.705587
# 2019-01-14  20.211735  21.923288   9.896587   4.551810
# 2019-01-15  12.195411  11.503071  19.827975   1.157487
# 2019-01-16  11.543593  11.587540   8.622696  23.794217
# ...

# %%
df.describe()
# Out:
#                A          B          C          D
# count  20.000000  20.000000  20.000000  20.000000
# mean   10.257525  13.266719  14.024956  11.297714
# std     6.015698   7.167364   8.358917   6.922115
# min     2.318826   0.673449   0.591164   1.157487
# 25%     4.918006   7.718703   7.794325   4.659553
# 50%     9.568588  12.347440  17.500675  11.484548
# 75%    13.753223  17.933148  20.729756  16.473515
# max    20.211735  24.794818  24.606552  23.794217

# %%
even = df[1::2]
odd = df[::2]

# %%
even.head()
# Out:
#                     A          B          C          D
# 2019-01-02   2.525761  17.401725  16.984277  20.994801
# 2019-01-04   6.994050  17.711561  19.150830   4.695468
# 2019-01-06   3.002424  17.806344  20.338848  12.292604
# 2019-01-08  12.931192  18.313562  22.255500  18.154234
# 2019-01-10   2.969376   5.089245  18.017073  20.464434

# %%
odd.head()
# Out:
#                     A          B          C          D
# 2019-01-01  13.373005  10.980024  24.606552   4.259944
# 2019-01-03  18.328276  23.166007   1.197484  15.913276
# 2019-01-05   8.820118   0.673449   8.533731  11.263508
# 2019-01-07   8.874312   6.764045   2.388930   6.592040
# 2019-01-09  14.893878   9.521947   1.805270   4.201258

# %%
odd.tail()
# Out:
#                     A          B          C          D
# 2019-01-11  19.158556  13.107341  23.153700   5.784614
# 2019-01-13   5.404057   7.942729  18.227000  11.705587
# 2019-01-15  12.195411  11.503071  19.827975   1.157487
# 2019-01-17  10.262865  22.569401  23.120009  14.525939
# 2019-01-19  19.431434  15.763468   5.576105   2.031870

# %%
odd.mean()
# Out:
# A    13.074191
# B    12.199148
# C    12.843676
# D     7.743552
# dtype: float64

# %%
even.mean()
# Out:
# A     7.440859
# B    14.334290
# C    15.206237
# D    14.851875
# dtype: float64

# %%
df
# Out:
#                     A          B          C          D
# 2019-01-01  13.373005  10.980024  24.606552   4.259944
# 2019-01-02   2.525761  17.401725  16.984277  20.994801
# 2019-01-03  18.328276  23.166007   1.197484  15.913276
# 2019-01-04   6.994050  17.711561  19.150830   4.695468
# 2019-01-05   8.820118   0.673449   8.533731  11.263508
# 2019-01-06   3.002424  17.806344  20.338848  12.292604
# 2019-01-07   8.874312   6.764045   2.388930   6.592040
# 2019-01-08  12.931192  18.313562  22.255500  18.154234
# 2019-01-09  14.893878   9.521947   1.805270   4.201258
# 2019-01-10   2.969376   5.089245  18.017073  20.464434
# 2019-01-11  19.158556  13.107341  23.153700   5.784614
# 2019-01-12   3.459850  24.794818   0.591164  10.028238
# 2019-01-13   5.404057   7.942729  18.227000  11.705587
# 2019-01-14  20.211735  21.923288   9.896587   4.551810
# 2019-01-15  12.195411  11.503071  19.827975   1.157487
# 2019-01-16  11.543593  11.587540   8.622696  23.794217
# ...

# %%
df[df > 20]
# Out:
#                     A          B          C          D
# 2019-01-01        NaN        NaN  24.606552        NaN
# 2019-01-02        NaN        NaN        NaN  20.994801
# 2019-01-03        NaN  23.166007        NaN        NaN
# 2019-01-04        NaN        NaN        NaN        NaN
# 2019-01-05        NaN        NaN        NaN        NaN
# 2019-01-06        NaN        NaN  20.338848        NaN
# 2019-01-07        NaN        NaN        NaN        NaN
# 2019-01-08        NaN        NaN  22.255500        NaN
# 2019-01-09        NaN        NaN        NaN        NaN
# 2019-01-10        NaN        NaN        NaN  20.464434
# 2019-01-11        NaN        NaN  23.153700        NaN
# 2019-01-12        NaN  24.794818        NaN        NaN
# 2019-01-13        NaN        NaN        NaN        NaN
# 2019-01-14  20.211735  21.923288        NaN        NaN
# 2019-01-15        NaN        NaN        NaN        NaN
# 2019-01-16        NaN        NaN        NaN  23.794217
# ...

# %%
df[ df['A'] > 18]
# Out:
#                     A          B          C          D
# 2019-01-03  18.328276  23.166007   1.197484  15.913276
# 2019-01-11  19.158556  13.107341  23.153700   5.784614
# 2019-01-14  20.211735  21.923288   9.896587   4.551810
# 2019-01-19  19.431434  15.763468   5.576105   2.031870

# %%
l = [ 

    [ 'Ram', 45000, 4, 'System Admin'],
    [ 'Shyam', 25000, 2 , 'Front End Developer'],
    [ 'Hari' , 15000, 1, 'DB admin'],
    [ 'Ghanshyam',56000,3,'Data Scientist']
]

# %%
df = pd.DataFrame(data=l,columns=['Name','Salary','Experience','Job Title'])

# %%
df.head()
# Out:
#         Name  Salary  Experience            Job Title
# 0        Ram   45000           4         System Admin
# 1      Shyam   25000           2  Front End Developer
# 2       Hari   15000           1             DB admin
# 3  Ghanshyam   56000           3       Data Scientist

# %%
df[df>25000]
# Out:
#         Name   Salary  Experience            Job Title
# 0        Ram  45000.0         NaN         System Admin
# 1      Shyam      NaN         NaN  Front End Developer
# 2       Hari      NaN         NaN             DB admin
# 3  Ghanshyam  56000.0         NaN       Data Scientist

# %%
df[df['Salary'] > 25000]
# Out:
#         Name  Salary  Experience       Job Title
# 0        Ram   45000           4    System Admin
# 3  Ghanshyam   56000           3  Data Scientist

# %%
df[[True,False,False,True]]
# Out:
#         Name  Salary  Experience       Job Title
# 0        Ram   45000           4    System Admin
# 3  Ghanshyam   56000           3  Data Scientist

# %%
df.query('Salary > 25000 ')
# Out:
#         Name  Salary  Experience       Job Title
# 0        Ram   45000           4    System Admin
# 3  Ghanshyam   56000           3  Data Scientist

# %%
df
# Out:
#         Name  Salary  Experience            Job Title
# 0        Ram   45000           4         System Admin
# 1      Shyam   25000           2  Front End Developer
# 2       Hari   15000           1             DB admin
# 3  Ghanshyam   56000           3       Data Scientist

# %%
df[['Name','Salary']]
# Out:
#         Name  Salary
# 0        Ram   45000
# 1      Shyam   25000
# 2       Hari   15000
# 3  Ghanshyam   56000

# %%
df.loc[0]
# Out:
# Name                   Ram
# Salary               45000
# Experience               4
# Job Title     System Admin
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# Name                        Shyam
# Salary                      25000
# Experience                      2
# Job Title     Front End Developer
# Name: 1, dtype: object

# %%
df.loc[1:3]
# Out:
#         Name  Salary  Experience            Job Title
# 1      Shyam   25000           2  Front End Developer
# 2       Hari   15000           1             DB admin
# 3  Ghanshyam   56000           3       Data Scientist

# %%
df
# Out:
#                     A          B          C          D
# 2019-01-01  13.373005  10.980024  24.606552   4.259944
# 2019-01-02   2.525761  17.401725  16.984277  20.994801
# 2019-01-03  18.328276  23.166007   1.197484  15.913276
# 2019-01-04   6.994050  17.711561  19.150830   4.695468
# 2019-01-05   8.820118   0.673449   8.533731  11.263508
# 2019-01-06   3.002424  17.806344  20.338848  12.292604
# 2019-01-07   8.874312   6.764045   2.388930   6.592040
# 2019-01-08  12.931192  18.313562  22.255500  18.154234
# 2019-01-09  14.893878   9.521947   1.805270   4.201258
# 2019-01-10   2.969376   5.089245  18.017073  20.464434
# 2019-01-11  19.158556  13.107341  23.153700   5.784614
# 2019-01-12   3.459850  24.794818   0.591164  10.028238
# 2019-01-13   5.404057   7.942729  18.227000  11.705587
# 2019-01-14  20.211735  21.923288   9.896587   4.551810
# 2019-01-15  12.195411  11.503071  19.827975   1.157487
# 2019-01-16  11.543593  11.587540   8.622696  23.794217
# ...

# %%
df[['A','D']]
# Out:
#                     A          D
# 2019-01-01  13.373005   4.259944
# 2019-01-02   2.525761  20.994801
# 2019-01-03  18.328276  15.913276
# 2019-01-04   6.994050   4.695468
# 2019-01-05   8.820118  11.263508
# 2019-01-06   3.002424  12.292604
# 2019-01-07   8.874312   6.592040
# 2019-01-08  12.931192  18.154234
# 2019-01-09  14.893878   4.201258
# 2019-01-10   2.969376  20.464434
# 2019-01-11  19.158556   5.784614
# 2019-01-12   3.459850  10.028238
# 2019-01-13   5.404057  11.705587
# 2019-01-14  20.211735   4.551810
# 2019-01-15  12.195411   1.157487
# 2019-01-16  11.543593  23.794217
# 2019-01-17  10.262865  14.525939
# 2019-01-18   2.318826  18.277933
# 2019-01-19  19.431434   2.031870
# 2019-01-20   8.451778  15.265013

# %%
df.loc['2019-01-15':'2019-01-20':2,['A','C']]
# Out:
#                     A          C
# 2019-01-15  12.195411  19.827975
# 2019-01-17  10.262865  23.120009
# 2019-01-19  19.431434   5.576105

# %%
df.loc['2019-01-05','B'] # single
# Out:
# 0.6734494614633407

# %%
df.iloc[0:15:2]
# Out:
#                     A          B          C          D
# 2019-01-01  13.373005  10.980024  24.606552   4.259944
# 2019-01-03  18.328276  23.166007   1.197484  15.913276
# 2019-01-05   8.820118   0.673449   8.533731  11.263508
# 2019-01-07   8.874312   6.764045   2.388930   6.592040
# 2019-01-09  14.893878   9.521947   1.805270   4.201258
# 2019-01-11  19.158556  13.107341  23.153700   5.784614
# 2019-01-13   5.404057   7.942729  18.227000  11.705587
# 2019-01-15  12.195411  11.503071  19.827975   1.157487

# %%
df.iat[5,2]
# Out:
# 20.338848233327987

# %%
df.at['2019-01-01','B'] #stack overflow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-263343094abd> in <module>
# ----> 1 df.at['2019-01-01','B'] #stack overflow
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2140
#    2141         key = self._convert_key(key)
# -> 2142         return self.obj._get_value(*key, takeable=self._takeable)
#    2143
#    2144     def __setitem__(self, key, value):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    2537
# ...

# %%
df['B'].plot()

# %%
df[['A','D']].plot(kind='hist',stacked=True)
plt.show()

# %%
df[['A','D']].plot(kind='box',stacked=True)
plt.show()

# %%
df.plot(x='A',y='C',kind='scatter',stacked=True,)
plt.show()
