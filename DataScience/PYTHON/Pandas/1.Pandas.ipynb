# %%
# DATA Wrangline Data Type 
# Series --> 1D array
# Data Frame --> 2D Table ( collection of series)

# %%
import pandas as pd

# %%
# creating series usin python data types
names = [ 'ram','shyam','ghanshyam','radheshyam','hariram']

# %%
s1 = pd.Series(names)

# %%
s1
# Out:
# 0           ram
# 1         shyam
# 2     ghanshyam
# 3    radheshyam
# 4       hariram
# dtype: object

# %%
s1[0]
# Out:
# 'ram'

# %%
s1[1:5]
# Out:
# 1         shyam
# 2     ghanshyam
# 3    radheshyam
# 4       hariram
# dtype: object

# %%
s1[::2]
# Out:
# 0          ram
# 2    ghanshyam
# 4      hariram
# dtype: object

# %%
# creating series usin python data types
names = [ 'ram','shyam','ghanshyam','radheshyam','hariram']
index =  [ 'A','B','C','D','E']

s2 = pd.Series(data=names,index=index)

# %%
s2
# Out:
# A           ram
# B         shyam
# C     ghanshyam
# D    radheshyam
# E       hariram
# dtype: object

# %%
s2[0]
# Out:
# 'ram'

# %%
s2[1:5]
# Out:
# B         shyam
# C     ghanshyam
# D    radheshyam
# E       hariram
# dtype: object

# %%
s2
# Out:
# A           ram
# B         shyam
# C     ghanshyam
# D    radheshyam
# E       hariram
# dtype: object

# %%
s2['A']
# Out:
# 'ram'

# %%
s2['D']
# Out:
# 'radheshyam'

# %%
s2['A':'C']
# Out:
# A          ram
# B        shyam
# C    ghanshyam
# dtype: object

# %%
date = pd.date_range(start="20190501",periods=5)

# %%
date
# Out:
# DatetimeIndex(['2019-05-01', '2019-05-02', '2019-05-03', '2019-05-04',
#                '2019-05-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
date = pd.date_range(start="20190501",periods=5,freq='M')

# %%
date
# Out:
# DatetimeIndex(['2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
date = pd.date_range(start="20190501",periods=5,freq='Y')
date
# Out:
# DatetimeIndex(['2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31',
#                '2023-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
date = pd.date_range(start='20190101',end='20190502')

# %%
date
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2019-04-23', '2019-04-24', '2019-04-25', '2019-04-26',
#                '2019-04-27', '2019-04-28', '2019-04-29', '2019-04-30',
#                '2019-05-01', '2019-05-02'],
#               dtype='datetime64[ns]', length=122, freq='D')

# %%
import numpy as np 
sell = np.random.randint(45,80,122)
sell
# Out:
# array([69, 47, 60, 65, 61, 73, 68, 71, 56, 72, 76, 61, 48, 67, 66, 71, 50,
#        72, 68, 46, 79, 76, 57, 74, 56, 62, 70, 75, 66, 75, 69, 47, 74, 63,
#        53, 52, 58, 73, 71, 65, 64, 73, 76, 65, 73, 52, 64, 61, 74, 56, 75,
#        72, 63, 60, 48, 79, 46, 45, 50, 67, 50, 69, 61, 74, 49, 58, 78, 67,
#        67, 48, 53, 57, 72, 45, 57, 51, 63, 59, 57, 71, 79, 59, 72, 77, 66,
#        67, 45, 55, 78, 51, 75, 67, 56, 68, 74, 52, 52, 64, 58, 47, 65, 51,
#        68, 56, 46, 58, 45, 59, 49, 50, 75, 66, 56, 72, 50, 69, 52, 78, 53,
#        70, 66, 56])

# %%
s = pd.Series(data=sell,index=date)

# %%
s.min()
# Out:
# 45

# %%
s.max()
# Out:
# 78

# %%
s.mean()
# Out:
# 62.221311475409834

# %%
s.median()
# Out:
# 62.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
s.plot(kind='hist')
plt.show()

# %%
name = [ 'sachin','rajat','kushal','nidhi']
age =  [ 23,33,25,25]
address = [ 'jaipur','ganganagar','udaipur','kota']

# %%
df = pd.DataFrame(data = { 
    'Name' : name,
    'Age' : age,
    'Address' : address
}, )

# %%
df
# Out:
#      Name  Age     Address
# 0  sachin   23      jaipur
# 1   rajat   33  ganganagar
# 2  kushal   25     udaipur
# 3   nidhi   25        kota

# %%
df['Age']
# Out:
# 0    23
# 1    33
# 2    25
# 3    25
# Name: Age, dtype: int64

# %%
df['Age'].mean()
# Out:
# 26.5

# %%
df[['Name','Address']]
# Out:
#      Name     Address
# 0  sachin      jaipur
# 1   rajat  ganganagar
# 2  kushal     udaipur
# 3   nidhi        kota

# %%
df[:5]
# Out:
#      Name  Age     Address
# 0  sachin   23      jaipur
# 1   rajat   33  ganganagar
# 2  kushal   25     udaipur
# 3   nidhi   25        kota

# %%
df[[True,False,True,True]]
# Out:
#      Name  Age  Address
# 0  sachin   23   jaipur
# 2  kushal   25  udaipur
# 3   nidhi   25     kota
