# %%
import requests

# %%
url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={}&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=AIzaSyDNqwMjAeyo8YyILwwNuSvuadLGf10gd9w"
place = input("Enter your place : ").replace(' ','%20')
url = url.format(place)
# Out:
# Enter your place : diggi, rajashtan

# %%
print(url)
# Out:
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=diggi,%20rajashtan&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=AIzaSyDNqwMjAeyo8YyILwwNuSvuadLGf10gd9w

# %%
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
data  = page.json()

# %%
data
# Out:
# {'candidates': [], 'status': 'INVALID_REQUEST'}

# %%
# Out:
# Enter your place : diggi, rajashtan
# {'candidates': [{'formatted_address': 'Diggi, Rajasthan 304504, India', 'geometry': {'location': {'lat': 26.3774143, 'lng': 75.437386}, 'viewport': {'northeast': {'lat': 26.3909471, 'lng': 75.4525566}, 'southwest': {'lat': 26.3689557, 'lng': 75.42766569999999}}}, 'name': 'Diggi', 'photos': [{'height': 1536, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104995262771170628885/photos">Manish jangid</a>'], 'photo_reference': 'CmRaAAAAjjSTO2mFYrucS8NvEOT8xQ9GzD2BWQAmArQwJItAMRLb8jSAnsmZvGU_Lb4x5ZU9kgh7nZxbTmFmgID8PNV9uUqSe2qGdxNIF3julwVrvwcFIilmgcNVNoE46CE1-IzBEhBthEaf5wG4nmR_5GWb_JBKGhRWGjBpiv-Xt2S5XUPhHLUiwKW1FA', 'width': 2048}], 'rating': 0}], 'status': 'OK'}

# %%
data.keys()
# Out:
# dict_keys(['candidates', 'status'])

# %%
data['status']
# Out:
# 'OK'

# %%
data['candidates'][0].keys()
# Out:
# dict_keys(['formatted_address', 'geometry', 'name', 'photos', 'rating'])

# %%
# Out:
# Place Name :-  Diggi, Rajasthan 304504, India

# %%
# Out:
# Latitute of your location is :  26.3774143
# Longitute of your location is :  75.437386

# %%
print(ph_ref)
new_url = "https://maps.googleapis.com/maps/api/place/photo?&photoreference={}&key=AIzaSyDNqwMjAeyo8YyILwwNuSvuadLGf10gd9w"
new_url = new_url.format(ph_ref)
photo = requests.get(new_url)
if photo.status_code == 200 : 
    f = open('new_img.jpg','wb')
    f.write(photo.content)
    f.close()
else : 
    print("no photo available")
# Out:
# CmRaAAAAjjSTO2mFYrucS8NvEOT8xQ9GzD2BWQAmArQwJItAMRLb8jSAnsmZvGU_Lb4x5ZU9kgh7nZxbTmFmgID8PNV9uUqSe2qGdxNIF3julwVrvwcFIilmgcNVNoE46CE1-IzBEhBthEaf5wG4nmR_5GWb_JBKGhRWGjBpiv-Xt2S5XUPhHLUiwKW1FA
# no photo available

# %%
p = requests.get(new_url)

# %%
p.status_code
# Out:
# 400

# %%
d = requests.get(url)

# %%
d.status_code
# Out:
# 200

# %%
d.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe1\x00*Exif\x00\x00II*\x00\x08\x00\x00\x00\x01\x001\x01\x02\x00\x07\x00\x00\x00\x1a\x00\x00\x00\x00\x00\x00\x00Google\x00\x00\xff\xdb\x00\x84\x00\x03\x02\x02\n\n\n\n\n\n\n\n\x0b\n\n\n\x08\n\n\n\n\n\n\n\n\n\x08\x08\x08\x08\x08\x08\x08\n\x08\n\n\n\n\n\n\x08\x08\x08\x08\x08\n\x08\n\n\n\n\n\n\x08\x08\r\r\n\x08\r\x08\x08\n\x08\x01\x03\x04\x04\x06\x05\x06\n\x06\x06\n\x10\r\x0b\x0e\x10\x0e\x0f\x0f\x0e\x0f\r\x0f\r\x0f\r\r\r\r\r\r\r\r\r\r\r\r\r\r\x0f\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\xff\xc0\x00\x11\x08\x01,\x01\x90\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x01\x05\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x03\x05\x06\x07\x08\x02\x01\x00\t\xff\xc4\x00[\x10\x00\x02\x01\x02\x04\x03\x03\x08\x06\x04\n\x07\x05\x06\x04\x07\x01\x02\x03\x04\x11\x00\x05\x12!\x06\x131\x07"A\x14Qaq\x81\x91\xa1\xb1\x08#2r\xc1\xf0BR\x82\xd1\x15\x163b\x92\xa2\xb2\xc2\xd2\xe1$CDE\xd3\xe2\xf1\tS\x83\x9
# ...

# %%
url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={}&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=AIzaSyDNqwMjAeyo8YyILwwNuSvuadLGf10gd9w"
place = input("Enter your place : ").replace(' ','%20')
url = url.format(place)
page = requests.get(url)
if page.status_code == 200 : 
    data = page.json()
else : 
    print("Check you internet connectivity or input")
name  = data['candidates'][0]['formatted_address']
print("Place Name :- ",name)
lat = data['candidates'][0]['geometry']['location']['lat']
long = data['candidates'][0]['geometry']['location']['lng']
print("Latitute of your location is : ",lat)
print("Longitute of your location is : ",long)
ph_ref = data['candidates'][0]['photos'][0]['photo_reference']
url = "https://maps.googleapis.com/maps/api/place/photo?maxwidth=400&photoreference={}&key=AIzaSyDNqwMjAeyo8YyILwwNuSvuadLGf10gd9w"
url = url.format(ph_ref)
page = requests.get(url)
f = open('imge.jpg','wb')
f.write(page.content)
f.close()
f = open('imge.jpg','rb')
img = plt.imread(f)
plt.imshow(img)
plt.show()
# Out:
# Enter your place : amer fort
# Place Name :-  Devisinghpura, Amer, Jaipur, Rajasthan 302001, India
# Latitute of your location is :  26.9854865
# Longitute of your location is :  75.8513454

# %%
import matplotlib.pyplot as plt
